# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the API key.
from config import weather_api_key
# Import citipy module
from citipy import citipy
# Import the requests library.
import requests

import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
print(url + '&q=' + 'Boston')
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce261f82e983a4340e46285c6f00842f&q=Boston

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | bubaque
# Processing Record 3 of Set 1 | kahului
# Processing Record 4 of Set 1 | cap malheureux
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | marzuq
# Processing Record 8 of Set 1 | jatai
# Processing Record 9 of Set 1 | vila
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | dingle
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | aasiaat
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | narasannapeta
# Processing Record 21 of Set 1 | vanimo
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | dutlwe
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | vardo
# Processing Record 26 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 27 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | grand gaube
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | sobolevo
# Processing Record 32 of Set 1 | lasa
# Processing Record 33 of Set 1 | saint-francois
# Processing Record 34 of Set 1 | sioux lookout
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | luchegorsk
# Processing Record 37 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | luwuk
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | wazzan
# City not found. Skipping...
# Processing Record 43 of Set 1 | mackenzie
# Processing Record 44 of Set 1 | atherton
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | acapulco
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | suez
# Processing Record 49 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | lata
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | woodward
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | katangi
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | cap-aux-meules
# Processing Record 14 of Set 2 | moerai
# Processing Record 15 of Set 2 | noumea
# Processing Record 16 of Set 2 | miraflores
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | staryy nadym
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | namibe
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | jalu
# Processing Record 28 of Set 2 | clyde river
# Processing Record 29 of Set 2 | pokhara
# Processing Record 30 of Set 2 | slobodskoy
# Processing Record 31 of Set 2 | timaru
# Processing Record 32 of Set 2 | monte santo
# Processing Record 33 of Set 2 | codrington
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | joaima
# Processing Record 36 of Set 2 | caravelas
# Processing Record 37 of Set 2 | solenzo
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | pucallpa
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | komsomolskiy
# Processing Record 42 of Set 2 | vao
# Processing Record 43 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | mataura
# Processing Record 46 of Set 2 | yaan
# Processing Record 47 of Set 2 | consolacion del sur
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | faanui
# Processing Record 1 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 3 | port blair
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | makung
# City not found. Skipping...
# Processing Record 7 of Set 3 | yining
# Processing Record 8 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 3 | sorland
# Processing Record 10 of Set 3 | murgab
# Processing Record 11 of Set 3 | tarauaca
# Processing Record 12 of Set 3 | chandbali
# Processing Record 13 of Set 3 | lincoln
# Processing Record 14 of Set 3 | chancay
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 3 | mocuba
# Processing Record 18 of Set 3 | mbouda
# Processing Record 19 of Set 3 | kiama
# Processing Record 20 of Set 3 | peniche
# Processing Record 21 of Set 3 | gizo
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | mahajanga
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | port lincoln
# Processing Record 28 of Set 3 | mehamn
# Processing Record 29 of Set 3 | keti bandar
# Processing Record 30 of Set 3 | nantucket
# Processing Record 31 of Set 3 | anadyr
# Processing Record 32 of Set 3 | jutiapa
# Processing Record 33 of Set 3 | talagang
# Processing Record 34 of Set 3 | orlik
# Processing Record 35 of Set 3 | maniitsoq
# Processing Record 36 of Set 3 | isangel
# Processing Record 37 of Set 3 | lorengau
# Processing Record 38 of Set 3 | chernyshkovskiy
# Processing Record 39 of Set 3 | nouakchott
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | mirabad
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | saint-pierre
# Processing Record 44 of Set 3 | sao pedro do sul
# Processing Record 45 of Set 3 | doha
# Processing Record 46 of Set 3 | faya
# Processing Record 47 of Set 3 | san luis
# Processing Record 48 of Set 3 | andenes
# Processing Record 49 of Set 3 | dudinka
# Processing Record 50 of Set 3 | havre-saint-pierre
# Processing Record 1 of Set 4 | raymondville
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | tura
# Processing Record 4 of Set 4 | bambous virieux
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | guerrero negro
# Processing Record 7 of Set 4 | quatre cocos
# Processing Record 8 of Set 4 | anar darreh
# City not found. Skipping...
# Processing Record 9 of Set 4 | roald
# Processing Record 10 of Set 4 | rawson
# Processing Record 11 of Set 4 | padang
# Processing Record 12 of Set 4 | san angelo
# Processing Record 13 of Set 4 | srednekolymsk
# Processing Record 14 of Set 4 | oktyabrskiy
# Processing Record 15 of Set 4 | hofn
# Processing Record 16 of Set 4 | corowa
# Processing Record 17 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 4 | michurinsk
# Processing Record 19 of Set 4 | lamu
# Processing Record 20 of Set 4 | qaanaaq
# Processing Record 21 of Set 4 | gainesville
# Processing Record 22 of Set 4 | chipinge
# Processing Record 23 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 4 | lewiston
# Processing Record 25 of Set 4 | dauriya
# Processing Record 26 of Set 4 | vila franca do campo
# Processing Record 27 of Set 4 | beaufort
# Processing Record 28 of Set 4 | galdar
# Processing Record 29 of Set 4 | pacific grove
# Processing Record 30 of Set 4 | deputatskiy
# Processing Record 31 of Set 4 | svetlogorsk
# Processing Record 32 of Set 4 | stabat
# Processing Record 33 of Set 4 | kargil
# Processing Record 34 of Set 4 | samarai
# Processing Record 35 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 4 | yulara
# Processing Record 38 of Set 4 | horta
# Processing Record 39 of Set 4 | maniwaki
# Processing Record 40 of Set 4 | tabas
# Processing Record 41 of Set 4 | puerto ayora
# Processing Record 42 of Set 4 | odweyne
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | mana
# Processing Record 45 of Set 4 | xai-xai
# Processing Record 46 of Set 4 | ferme-neuve
# Processing Record 47 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 4 | abha
# Processing Record 49 of Set 4 | siva
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | tukrah
# Processing Record 2 of Set 5 | bazpur
# Processing Record 3 of Set 5 | port macquarie
# Processing Record 4 of Set 5 | tonantins
# Processing Record 5 of Set 5 | camacha
# Processing Record 6 of Set 5 | gushikawa
# Processing Record 7 of Set 5 | prince rupert
# Processing Record 8 of Set 5 | la rioja
# Processing Record 9 of Set 5 | bria
# Processing Record 10 of Set 5 | hamilton
# Processing Record 11 of Set 5 | joshimath
# Processing Record 12 of Set 5 | westport
# Processing Record 13 of Set 5 | ankazoabo
# Processing Record 14 of Set 5 | malanje
# Processing Record 15 of Set 5 | yatou
# Processing Record 16 of Set 5 | ulaangom
# Processing Record 17 of Set 5 | rafraf
# Processing Record 18 of Set 5 | lavrentiya
# Processing Record 19 of Set 5 | deda
# Processing Record 20 of Set 5 | sakakah
# Processing Record 21 of Set 5 | terrace
# Processing Record 22 of Set 5 | goure
# Processing Record 23 of Set 5 | aquiraz
# Processing Record 24 of Set 5 | abu dhabi
# Processing Record 25 of Set 5 | grand baie
# Processing Record 26 of Set 5 | georgetown
# Processing Record 27 of Set 5 | waipawa
# Processing Record 28 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5 | ostrovnoy
# Processing Record 30 of Set 5 | kieta
# Processing Record 31 of Set 5 | tshikapa
# Processing Record 32 of Set 5 | yellowknife
# Processing Record 33 of Set 5 | alofi
# Processing Record 34 of Set 5 | lerik
# Processing Record 35 of Set 5 | esterhazy
# Processing Record 36 of Set 5 | beira
# Processing Record 37 of Set 5 | san juan
# Processing Record 38 of Set 5 | akdepe
# Processing Record 39 of Set 5 | lagoa
# Processing Record 40 of Set 5 | baie-saint-paul
# Processing Record 41 of Set 5 | savonlinna
# Processing Record 42 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 5 | castro
# Processing Record 44 of Set 5 | kilindoni
# Processing Record 45 of Set 5 | panjwin
# City not found. Skipping...
# Processing Record 46 of Set 5 | cedar city
# Processing Record 47 of Set 5 | mangan
# Processing Record 48 of Set 5 | labuhan
# Processing Record 49 of Set 5 | kaeo
# Processing Record 50 of Set 5 | lakatoro
# Processing Record 1 of Set 6 | coihaique
# Processing Record 2 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 6 | san cristobal
# Processing Record 4 of Set 6 | traverse city
# Processing Record 5 of Set 6 | subaytilah
# City not found. Skipping...
# Processing Record 6 of Set 6 | vostok
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | vestmannaeyjar
# Processing Record 10 of Set 6 | zhezkazgan
# Processing Record 11 of Set 6 | farah
# Processing Record 12 of Set 6 | ntungamo
# Processing Record 13 of Set 6 | hasaki
# Processing Record 14 of Set 6 | douglas
# Processing Record 15 of Set 6 | chuy
# Processing Record 16 of Set 6 | flinders
# Processing Record 17 of Set 6 | marawi
# Processing Record 18 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 19 of Set 6 | milledgeville
# Processing Record 20 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 6 | severnyy
# Processing Record 22 of Set 6 | carutapera
# Processing Record 23 of Set 6 | dhidhdhoo
# Processing Record 24 of Set 6 | hit
# Processing Record 25 of Set 6 | trapani
# Processing Record 26 of Set 6 | marsa matruh
# Processing Record 27 of Set 6 | oster
# Processing Record 28 of Set 6 | lebu
# Processing Record 29 of Set 6 | east london
# Processing Record 30 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 6 | san jose
# Processing Record 32 of Set 6 | sapu
# Processing Record 33 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 6 | longhua
# Processing Record 35 of Set 6 | tilichiki
# Processing Record 36 of Set 6 | stornoway
# Processing Record 37 of Set 6 | touros
# Processing Record 38 of Set 6 | victoria
# Processing Record 39 of Set 6 | okhotsk
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | asau
# Processing Record 42 of Set 6 | luganville
# Processing Record 43 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 44 of Set 6 | iqaluit
# Processing Record 45 of Set 6 | sakaiminato
# Processing Record 46 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 6 | gat
# Processing Record 48 of Set 6 | hobyo
# Processing Record 49 of Set 6 | conceicao do araguaia
# Processing Record 50 of Set 6 | kathu
# Processing Record 1 of Set 7 | half moon bay
# Processing Record 2 of Set 7 | bundaberg
# Processing Record 3 of Set 7 | effingham
# Processing Record 4 of Set 7 | omboue
# Processing Record 5 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 7 | menongue
# Processing Record 7 of Set 7 | krasnoselkup
# Processing Record 8 of Set 7 | igarka
# Processing Record 9 of Set 7 | arman
# Processing Record 10 of Set 7 | adrar
# Processing Record 11 of Set 7 | sungaipenuh
# Processing Record 12 of Set 7 | kavaratti
# Processing Record 13 of Set 7 | sunrise manor
# Processing Record 14 of Set 7 | bilibino
# Processing Record 15 of Set 7 | bengkulu
# Processing Record 16 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 7 | edgewater
# Processing Record 20 of Set 7 | mitsamiouli
# Processing Record 21 of Set 7 | la ronge
# Processing Record 22 of Set 7 | west lafayette
# Processing Record 23 of Set 7 | ancud
# Processing Record 24 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 7 | airai
# Processing Record 26 of Set 7 | ransang
# Processing Record 27 of Set 7 | valday
# Processing Record 28 of Set 7 | saldanha
# Processing Record 29 of Set 7 | souillac
# Processing Record 30 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 7 | solna
# Processing Record 32 of Set 7 | karratha
# Processing Record 33 of Set 7 | pahalgam
# Processing Record 34 of Set 7 | la fleche
# Processing Record 35 of Set 7 | nambucca heads
# Processing Record 36 of Set 7 | qostanay
# Processing Record 37 of Set 7 | trincomalee
# Processing Record 38 of Set 7 | manta
# Processing Record 39 of Set 7 | senador jose porfirio
# Processing Record 40 of Set 7 | yelkhovka
# Processing Record 41 of Set 7 | zhanaozen
# Processing Record 42 of Set 7 | leningradskiy
# Processing Record 43 of Set 7 | burnie
# Processing Record 44 of Set 7 | gillette
# Processing Record 45 of Set 7 | haapu
# City not found. Skipping...
# Processing Record 46 of Set 7 | teguldet
# Processing Record 47 of Set 7 | general roca
# Processing Record 48 of Set 7 | haines junction
# Processing Record 49 of Set 7 | kropotkin
# Processing Record 50 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 1 of Set 8 | urengoy
# Processing Record 2 of Set 8 | akureyri
# Processing Record 3 of Set 8 | vaitape
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | florence
# Processing Record 6 of Set 8 | poum
# Processing Record 7 of Set 8 | xiongshi
# City not found. Skipping...
# Processing Record 8 of Set 8 | nouadhibou
# Processing Record 9 of Set 8 | inhambane
# Processing Record 10 of Set 8 | port maria
# Processing Record 11 of Set 8 | huaibei
# Processing Record 12 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 8 | talnakh
# Processing Record 14 of Set 8 | ponta do sol
# Processing Record 15 of Set 8 | vila velha
# Processing Record 16 of Set 8 | pamanukan
# Processing Record 17 of Set 8 | avera
# Processing Record 18 of Set 8 | belmonte
# Processing Record 19 of Set 8 | zelenogradsk
# Processing Record 20 of Set 8 | hay river
# Processing Record 21 of Set 8 | hailar
# Processing Record 22 of Set 8 | dunedin
# Processing Record 23 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 8 | isfana
# Processing Record 25 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 27 of Set 8 | raudeberg
# Processing Record 28 of Set 8 | burkhala
# City not found. Skipping...
# Processing Record 29 of Set 8 | maham
# Processing Record 30 of Set 8 | longyearbyen
# Processing Record 31 of Set 8 | laguna
# Processing Record 32 of Set 8 | humberto de campos
# Processing Record 33 of Set 8 | pauini
# Processing Record 34 of Set 8 | nobres
# Processing Record 35 of Set 8 | tortoli
# Processing Record 36 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 37 of Set 8 | sikea
# City not found. Skipping...
# Processing Record 38 of Set 8 | itarema
# Processing Record 39 of Set 8 | boulder city
# Processing Record 40 of Set 8 | plouzane
# Processing Record 41 of Set 8 | thinadhoo
# Processing Record 42 of Set 8 | pangnirtung
# Processing Record 43 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 8 | cockburn town
# Processing Record 45 of Set 8 | soyo
# Processing Record 46 of Set 8 | otofuke
# Processing Record 47 of Set 8 | cabo san lucas
# Processing Record 48 of Set 8 | trinidad
# Processing Record 49 of Set 8 | olinda
# Processing Record 50 of Set 8 | naze
# Processing Record 1 of Set 9 | kikwit
# Processing Record 2 of Set 9 | hovd
# Processing Record 3 of Set 9 | buala
# Processing Record 4 of Set 9 | suntar
# Processing Record 5 of Set 9 | shurugwi
# Processing Record 6 of Set 9 | yar-sale
# Processing Record 7 of Set 9 | nago
# Processing Record 8 of Set 9 | atambua
# Processing Record 9 of Set 9 | eatonton
# Processing Record 10 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 11 of Set 9 | farmington
# Processing Record 12 of Set 9 | fort morgan
# Processing Record 13 of Set 9 | namatanai
# Processing Record 14 of Set 9 | bathsheba
# Processing Record 15 of Set 9 | lisala
# Processing Record 16 of Set 9 | mogadishu
# Processing Record 17 of Set 9 | sitka
# Processing Record 18 of Set 9 | jishou
# Processing Record 19 of Set 9 | saiha
# Processing Record 20 of Set 9 | broome
# Processing Record 21 of Set 9 | shibarghan
# City not found. Skipping...
# Processing Record 22 of Set 9 | san jeronimo
# Processing Record 23 of Set 9 | sabha
# Processing Record 24 of Set 9 | mega
# Processing Record 25 of Set 9 | zhigansk
# Processing Record 26 of Set 9 | freeport
# Processing Record 27 of Set 9 | shubarshi
# Processing Record 28 of Set 9 | devils lake
# Processing Record 29 of Set 9 | barabai
# Processing Record 30 of Set 9 | sinnamary
# Processing Record 31 of Set 9 | maragogi
# Processing Record 32 of Set 9 | tekeli
# Processing Record 33 of Set 9 | elati
# Processing Record 34 of Set 9 | beringovskiy
# Processing Record 35 of Set 9 | ararat
# Processing Record 36 of Set 9 | kamaishi
# Processing Record 37 of Set 9 | bintulu
# Processing Record 38 of Set 9 | fairbanks
# Processing Record 39 of Set 9 | lausen
# Processing Record 40 of Set 9 | fortuna
# Processing Record 41 of Set 9 | casale monferrato
# Processing Record 42 of Set 9 | marystown
# Processing Record 43 of Set 9 | issoire
# Processing Record 44 of Set 9 | kachkanar
# Processing Record 45 of Set 9 | henties bay
# Processing Record 46 of Set 9 | nokaneng
# Processing Record 47 of Set 9 | acari
# Processing Record 48 of Set 9 | robertsganj
# Processing Record 49 of Set 9 | huejuquilla el alto
# Processing Record 50 of Set 9 | karakose
# City not found. Skipping...
# Processing Record 1 of Set 10 | lazaro cardenas
# Processing Record 2 of Set 10 | batemans bay
# Processing Record 3 of Set 10 | bonavista
# Processing Record 4 of Set 10 | shar
# Processing Record 5 of Set 10 | shreveport
# Processing Record 6 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 7 of Set 10 | praia
# Processing Record 8 of Set 10 | vidalia
# Processing Record 9 of Set 10 | pachino
# Processing Record 10 of Set 10 | matay
# Processing Record 11 of Set 10 | mashhad
# Processing Record 12 of Set 10 | saint-augustin
# Processing Record 13 of Set 10 | oistins
# Processing Record 14 of Set 10 | realeza
# Processing Record 15 of Set 10 | north bend
# Processing Record 16 of Set 10 | necochea
# Processing Record 17 of Set 10 | jiayuguan
# Processing Record 18 of Set 10 | pedernales
# Processing Record 19 of Set 10 | jeremie
# Processing Record 20 of Set 10 | muros
# Processing Record 21 of Set 10 | atlantic beach
# Processing Record 22 of Set 10 | ilave
# Processing Record 23 of Set 10 | hamadan
# Processing Record 24 of Set 10 | pierre
# Processing Record 25 of Set 10 | miranda
# Processing Record 26 of Set 10 | nailon
# Processing Record 27 of Set 10 | sao joao da barra
# Processing Record 28 of Set 10 | chino valley
# Processing Record 29 of Set 10 | coahuayana
# Processing Record 30 of Set 10 | el juncal
# Processing Record 31 of Set 10 | ponta delgada
# Processing Record 32 of Set 10 | parakou
# Processing Record 33 of Set 10 | korla
# Processing Record 34 of Set 10 | shimoda
# Processing Record 35 of Set 10 | sainte-marie
# Processing Record 36 of Set 10 | ondarroa
# Processing Record 37 of Set 10 | lucea
# Processing Record 38 of Set 10 | qaqortoq
# Processing Record 39 of Set 10 | yeppoon
# Processing Record 40 of Set 10 | san vicente
# Processing Record 41 of Set 10 | ilesha
# Processing Record 42 of Set 10 | khorixas
# Processing Record 43 of Set 10 | yakeshi
# Processing Record 44 of Set 10 | amga
# Processing Record 45 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 10 | pimenta bueno
# Processing Record 47 of Set 10 | tevaitoa
# Processing Record 48 of Set 10 | villarrica
# Processing Record 49 of Set 10 | phultala
# Processing Record 50 of Set 10 | port hardy
# Processing Record 1 of Set 11 | calpan
# City not found. Skipping...
# Processing Record 2 of Set 11 | turayf
# Processing Record 3 of Set 11 | gumushane
# City not found. Skipping...
# Processing Record 4 of Set 11 | buta
# Processing Record 5 of Set 11 | barinitas
# Processing Record 6 of Set 11 | poykovskiy
# Processing Record 7 of Set 11 | taltal
# Processing Record 8 of Set 11 | tsabong
# Processing Record 9 of Set 11 | araouane
# Processing Record 10 of Set 11 | sibolga
# Processing Record 11 of Set 11 | olafsvik
# Processing Record 12 of Set 11 | tazovskiy
# Processing Record 13 of Set 11 | obera
# Processing Record 14 of Set 11 | kasama
# Processing Record 15 of Set 11 | khilok
# Processing Record 16 of Set 11 | agva
# City not found. Skipping...
# Processing Record 17 of Set 11 | atocha
# Processing Record 18 of Set 11 | feicheng
# Processing Record 19 of Set 11 | tateyama
# Processing Record 20 of Set 11 | rio grande
# Processing Record 21 of Set 11 | fort nelson
# Processing Record 22 of Set 11 | hudiksvall
# Processing Record 23 of Set 11 | samfya
# Processing Record 24 of Set 11 | charters towers
# Processing Record 25 of Set 11 | huayucachi
# Processing Record 26 of Set 11 | alenquer
# Processing Record 27 of Set 11 | nosy varika
# Processing Record 28 of Set 11 | rudnogorsk
# Processing Record 29 of Set 11 | tezu
# Processing Record 30 of Set 11 | panuco
# Processing Record 31 of Set 11 | rosarito
# Processing Record 32 of Set 11 | mahibadhoo
# Processing Record 33 of Set 11 | sokur
# Processing Record 34 of Set 11 | wajir
# Processing Record 35 of Set 11 | otawara
# Processing Record 36 of Set 11 | bairiki
# Processing Record 37 of Set 11 | jiancheng
# Processing Record 38 of Set 11 | linguere
# Processing Record 39 of Set 11 | novyy urengoy
# Processing Record 40 of Set 11 | ixhuatan
# Processing Record 41 of Set 11 | bageshwar
# Processing Record 42 of Set 11 | arlit
# Processing Record 43 of Set 11 | fairmont
# Processing Record 44 of Set 11 | yangambi
# Processing Record 45 of Set 11 | mount gambier
# Processing Record 46 of Set 11 | takoradi
# Processing Record 47 of Set 11 | shpykiv
# City not found. Skipping...
# Processing Record 48 of Set 11 | powell
# Processing Record 49 of Set 11 | goderich
# Processing Record 50 of Set 11 | baykit
# Processing Record 1 of Set 12 | morondava
# Processing Record 2 of Set 12 | rabo de peixe
# Processing Record 3 of Set 12 | xuddur
# Processing Record 4 of Set 12 | melita
# Processing Record 5 of Set 12 | terme
# Processing Record 6 of Set 12 | malmyzh
# Processing Record 7 of Set 12 | prainha
# Processing Record 8 of Set 12 | slave lake
# Processing Record 9 of Set 12 | braco do norte
# Processing Record 10 of Set 12 | jardim
# Processing Record 11 of Set 12 | cayhagan
# Processing Record 12 of Set 12 | eureka
# Processing Record 13 of Set 12 | leshukonskoye
# Processing Record 14 of Set 12 | san carlos de bariloche
# Processing Record 15 of Set 12 | marrakesh
# Processing Record 16 of Set 12 | oranjestad
# Processing Record 17 of Set 12 | santa maria
# Processing Record 18 of Set 12 | sur
# Processing Record 19 of Set 12 | meulaboh
# Processing Record 20 of Set 12 | ahuimanu
# Processing Record 21 of Set 12 | edmundston
# Processing Record 22 of Set 12 | petropavlovka
# Processing Record 23 of Set 12 | valparaiso
# Processing Record 24 of Set 12 | uyuni
# Processing Record 25 of Set 12 | mersing
# Processing Record 26 of Set 12 | grindavik
# Processing Record 27 of Set 12 | sao filipe
# Processing Record 28 of Set 12 | dicabisagan
# Processing Record 29 of Set 12 | hambantota
# Processing Record 30 of Set 12 | comodoro rivadavia
# Processing Record 31 of Set 12 | consett
# Processing Record 32 of Set 12 | mayo
# Processing Record 33 of Set 12 | bereda
# Processing Record 34 of Set 12 | harindanga
# Processing Record 35 of Set 12 | lagunas
# Processing Record 36 of Set 12 | piacabucu
# Processing Record 37 of Set 12 | rincon
# Processing Record 38 of Set 12 | kaspiyskiy
# Processing Record 39 of Set 12 | nishihara
# Processing Record 40 of Set 12 | atka
# City not found. Skipping...
# Processing Record 41 of Set 12 | puerto del rosario
# Processing Record 42 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 43 of Set 12 | linkuva
# Processing Record 44 of Set 12 | puerto madryn
# Processing Record 45 of Set 12 | kidal
# Processing Record 46 of Set 12 | santa marta
# Processing Record 47 of Set 12 | krasnoarmeysk
# Processing Record 48 of Set 12 | kununurra
# Processing Record 49 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 13 | emerald
# Processing Record 2 of Set 13 | matara
# Processing Record 3 of Set 13 | houma
# Processing Record 4 of Set 13 | corsicana
# Processing Record 5 of Set 13 | uvelskiy
# Processing Record 6 of Set 13 | dzaoudzi
# Processing Record 7 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 8 of Set 13 | eldoret
# Processing Record 9 of Set 13 | salgueiro
# Processing Record 10 of Set 13 | hailey
# Processing Record 11 of Set 13 | senador guiomard
# Processing Record 12 of Set 13 | richards bay
# Processing Record 13 of Set 13 | hirara
# Processing Record 14 of Set 13 | kuytun
# Processing Record 15 of Set 13 | ettenheim
# Processing Record 16 of Set 13 | tabou
# Processing Record 17 of Set 13 | sikasso
# Processing Record 18 of Set 13 | beyneu
# Processing Record 19 of Set 13 | mattru
# Processing Record 20 of Set 13 | benito juarez
# Processing Record 21 of Set 13 | kotido
# Processing Record 22 of Set 13 | maihar
# Processing Record 23 of Set 13 | dossor
# Processing Record 24 of Set 13 | cururupu
# Processing Record 25 of Set 13 | tank
# Processing Record 26 of Set 13 | arys
# Processing Record 27 of Set 13 | coquimbo
# Processing Record 28 of Set 13 | evensk
# Processing Record 29 of Set 13 | dukat
# Processing Record 30 of Set 13 | iranshahr
# Processing Record 31 of Set 13 | banes
# Processing Record 32 of Set 13 | alice springs
# Processing Record 33 of Set 13 | mithimna
# City not found. Skipping...
# Processing Record 34 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 13 | thurso
# Processing Record 36 of Set 13 | balabac
# Processing Record 37 of Set 13 | kudahuvadhoo
# Processing Record 38 of Set 13 | jacksonville
# Processing Record 39 of Set 13 | san patricio
# Processing Record 40 of Set 13 | salinopolis
# Processing Record 41 of Set 13 | yumen
# Processing Record 42 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 43 of Set 13 | kontagora
# Processing Record 44 of Set 13 | atar
# Processing Record 45 of Set 13 | bani
# Processing Record 46 of Set 13 | abu zabad
# Processing Record 47 of Set 13 | kachug
# Processing Record 48 of Set 13 | brae
# Processing Record 49 of Set 13 | bitung
# Processing Record 50 of Set 13 | caibarien
# Processing Record 1 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 2 of Set 14 | djambala
# Processing Record 3 of Set 14 | viedma
# Processing Record 4 of Set 14 | sao joao evangelista
# Processing Record 5 of Set 14 | jumla
# Processing Record 6 of Set 14 | wladyslawowo
# Processing Record 7 of Set 14 | lerwick
# Processing Record 8 of Set 14 | dubbo
# Processing Record 9 of Set 14 | lake jackson
# Processing Record 10 of Set 14 | hastings
# Processing Record 11 of Set 14 | foix
# Processing Record 12 of Set 14 | eyl
# Processing Record 13 of Set 14 | nalut
# Processing Record 14 of Set 14 | bangaon
# Processing Record 15 of Set 14 | lompoc
# Processing Record 16 of Set 14 | juneau
# Processing Record 17 of Set 14 | loralai
# Processing Record 18 of Set 14 | rio gallegos
# Processing Record 19 of Set 14 | grand-santi
# Processing Record 20 of Set 14 | katsuura
# Processing Record 21 of Set 14 | nome
# Processing Record 22 of Set 14 | timizart
# Processing Record 23 of Set 14 | magadan
# Processing Record 24 of Set 14 | ust-omchug
# Processing Record 25 of Set 14 | ketchikan
# Processing Record 26 of Set 14 | machali
# Processing Record 27 of Set 14 | abu samrah
# Processing Record 28 of Set 14 | aloleng
# Processing Record 29 of Set 14 | tommot
# Processing Record 30 of Set 14 | edendale
# Processing Record 31 of Set 14 | la sarre
# Processing Record 32 of Set 14 | middelkerke
# Processing Record 33 of Set 14 | roma
# Processing Record 34 of Set 14 | itoman
# Processing Record 35 of Set 14 | innisfail
# Processing Record 36 of Set 14 | cairns
# Processing Record 37 of Set 14 | swan hill
# Processing Record 38 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 14 | mecca
# Processing Record 40 of Set 14 | manbij
# Processing Record 41 of Set 14 | mangrol
# Processing Record 42 of Set 14 | kimbe
# Processing Record 43 of Set 14 | apostolove
# Processing Record 44 of Set 14 | methoni
# Processing Record 45 of Set 14 | colac
# Processing Record 46 of Set 14 | sechura
# Processing Record 47 of Set 14 | svobodnyy
# Processing Record 48 of Set 14 | uray
# Processing Record 49 of Set 14 | kedrovyy
# Processing Record 50 of Set 14 | belaya gora
# Processing Record 1 of Set 15 | aksay
# Processing Record 2 of Set 15 | shirokiy
# Processing Record 3 of Set 15 | gwadar
# Processing Record 4 of Set 15 | mariental
# Processing Record 5 of Set 15 | iraquara
# Processing Record 6 of Set 15 | ribnica
# Processing Record 7 of Set 15 | kodino
# Processing Record 8 of Set 15 | mareeba
# Processing Record 9 of Set 15 | klyuchi
# Processing Record 10 of Set 15 | katherine
# Processing Record 11 of Set 15 | bud
# Processing Record 12 of Set 15 | tocache
# Processing Record 13 of Set 15 | berbera
# Processing Record 14 of Set 15 | portland
# Processing Record 15 of Set 15 | bouca
# Processing Record 16 of Set 15 | maur
# Processing Record 17 of Set 15 | luderitz
# Processing Record 18 of Set 15 | kemin
# Processing Record 19 of Set 15 | balykshi
# Processing Record 20 of Set 15 | merauke
# Processing Record 21 of Set 15 | rocha
# Processing Record 22 of Set 15 | basavana bagevadi
# Processing Record 23 of Set 15 | arvika
# Processing Record 24 of Set 15 | auburn
# Processing Record 25 of Set 15 | kulhudhuffushi
# Processing Record 26 of Set 15 | oga
# Processing Record 27 of Set 15 | migori
# Processing Record 28 of Set 15 | belyy yar
# Processing Record 29 of Set 15 | sao felix do xingu
# Processing Record 30 of Set 15 | flagstaff
# Processing Record 31 of Set 15 | itaituba
# Processing Record 32 of Set 15 | shubarkuduk
# Processing Record 33 of Set 15 | onega
# Processing Record 34 of Set 15 | egvekinot
# Processing Record 35 of Set 15 | odienne
# Processing Record 36 of Set 15 | salina cruz
# Processing Record 37 of Set 15 | gidole
# Processing Record 38 of Set 15 | lubango
# Processing Record 39 of Set 15 | wapi pathum
# Processing Record 40 of Set 15 | olkhovka
# Processing Record 41 of Set 15 | rancho palos verdes
# Processing Record 42 of Set 15 | mopipi
# Processing Record 43 of Set 15 | togur
# Processing Record 44 of Set 15 | husavik
# Processing Record 45 of Set 15 | witu
# Processing Record 46 of Set 15 | omsukchan
# Processing Record 47 of Set 15 | makakilo city
# Processing Record 48 of Set 15 | todos santos
# Processing Record 49 of Set 15 | klaksvik
# Processing Record 50 of Set 15 | parnarama
# Processing Record 1 of Set 16 | gannan
# Processing Record 2 of Set 16 | ukiah
# Processing Record 3 of Set 16 | paris
# Processing Record 4 of Set 16 | veraval
# Processing Record 5 of Set 16 | carman
# Processing Record 6 of Set 16 | tessalit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tuatapere      NZ -46.1333  167.6833     34.93        90          44
# 1         Bubaque      GW  11.2833  -15.8333     80.58        80         100
# 2         Kahului      US  20.8947 -156.4700     84.97        84          16
# 3  Cap Malheureux      MU -19.9842   57.6142     68.47        84          84
# 4       Busselton      AU -33.6500  115.3333     58.59        64         100
#
#    Wind Speed Current Description
# 0        5.77    scattered clouds
# 1       14.12     overcast clouds
# 2       10.00          few clouds
# 3        5.01          light rain
# 4        3.04     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label = "City_ID")
